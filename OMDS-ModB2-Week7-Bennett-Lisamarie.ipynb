# %% [markdown]
# # Week 7 - Milestone One week

# %% [markdown]
# # 1. Lesson: no lesson this week.  Milestone One is due!

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# Below are the graphs from last week's weekly graph question.  Suppose you wanted to cause the viewer to examine the last three months of data first.  How could you use preattentive attributes to do that?  Suggest several possibilities.

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
numdates = 12
np.random.seed(0)
time_series = 100 * (np.random.normal(size = numdates) / 5 + np.arange(numdates) / 16)
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Nitrate level (% of eutrophic value)")
# Out:
# C:\Users\annma\AppData\Local\Temp\ipykernel_28568\2149468501.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Nitrate level (% of eutrophic value)')

# %%
np.random.seed(1)
time_series = 100 * (1 - (np.random.normal(size = numdates) / 8 + np.arange(numdates) / 16))
datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
ax = sns.lineplot(x = datearray, y = time_series)
ax.set_xlabel("Year and month")
ax.set_ylabel("Phosphate level (% of eutrophic value)")
# Out:
# C:\Users\annma\AppData\Local\Temp\ipykernel_28568\1012779568.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   datearray = pd.date_range(start='2023/01/01', end='2024/01/01', freq='M')
# Text(0, 0.5, 'Phosphate level (% of eutrophic value)')

# %% [markdown]
# Something you can do are:
#
# Make the last three months a bold color, like red or bright orange or in my case pink
#
# Use circle markers, triangles, or stars only on the last three months' data points.
#
# Add labels or text annotations like “Recent spike” or “Lowest point here.”

# %% [markdown]
# # 3. Working on your datasets
#
# This week, you can work on Milestone One rather than having a particular exercise about working on your datasets

# %% [markdown]
# # 4. Storytelling With Data plot
#
# Reproduce any graph of your choice in p. 99-119 of the Storytelling With Data book as best you can. (The first half of chapter four). You do not have to get the exact data values right, just the overall look and feel.

# %%
# Data
rows = [
    "756395068473",
    "658663037576",
    "860372658602",
    "846589107830"
]

# Plot
fig, ax = plt.subplots(figsize=(14, 6))
ax.axis("off")

# Draw characters
for y, row in enumerate(rows):
    for x, digit in enumerate(row):
        ax.text(
            x, -y, digit,
            fontsize=80,
            fontweight='bold' if digit == "3" else 'normal',
            color='black' if digit == "3" else 'lightgray',
            family='monospace',
            ha='center', va='center'
        )

# Add caption
ax.text(0, -len(rows) - 0.8,
        "FIGURE 4.3   Count the 3s example with preattentive attributes",
        fontsize=18,
        color='gray',
        ha='left')

# Save to file
plt.savefig("count_the_3s.png", dpi=300, bbox_inches='tight')
plt.close()
